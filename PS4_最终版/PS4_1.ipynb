# %%
# Import modules
import numpy as np
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import cartopy.crs as ccrs
import cartopy.feature as cfeature
# %matplotlib inline

# %%
#载入地震数据
Sig_Eqs = pd.read_csv('usgs_earthquakes.csv',sep=',')

#预览数据
Sig_Eqs
# Out:
#                            time   latitude   longitude   depth   mag magType  \
# 0       2014-01-31 23:53:37.000  60.252000 -152.708100   90.20  1.10      ml
# 1       2014-01-31 23:48:35.452  37.070300 -115.130900    0.00  1.33      ml
# 2       2014-01-31 23:47:24.000  64.671700 -149.252800    7.10  1.30      ml
# 3       2014-01-31 23:30:54.000  63.188700 -148.957500   96.50  0.80      ml
# 4       2014-01-31 23:30:52.210  32.616833 -115.692500   10.59  1.34      ml
# ...                         ...        ...         ...     ...   ...     ...
# 120103  2014-12-01 00:10:16.000  60.963900 -146.762900   14.80  3.80      ml
# 120104  2014-12-01 00:09:39.000  58.869100 -154.415900  108.40  2.40      ml
# 120105  2014-12-01 00:09:25.350  38.843498 -122.825836    2.37  0.43      md
# 120106  2014-12-01 00:05:54.000  65.152100 -148.992000    9.50  0.40      ml
# 120107  2014-12-01 00:04:05.000  60.227200 -147.024500    2.50  1.60      ml
#
# ...

# %%
#获取2014年全球的Top50地震发生的位置

#建立只包含年份的新列
Sig_Eqs['year'] = pd.DatetimeIndex(Sig_Eqs['time']).year

#提取2014年的地震级数Top50数据
Sig_Eqs_top50 = Sig_Eqs[Sig_Eqs['year']==2014].sort_values('mag',ascending=False)[:50]
Sig_Eqs_top50.reset_index(drop=True, inplace=True)
Sig_Eqs_top50 #Sig_Eqs_top50包含了经纬度信息
# Out:
#                        time  latitude  longitude   depth  mag magType  nst  \
# 0   2014-04-01 23:46:47.260  -19.6097   -70.7691   25.00  8.2     mww  NaN
# 1   2014-06-23 20:53:09.700   51.8486   178.7352  109.00  7.9     mww  NaN
# 2   2014-04-03 02:43:13.110  -20.5709   -70.4931   22.40  7.7     mww  NaN
# 3   2014-04-12 20:14:39.300  -11.2701   162.1481   22.56  7.6     mww  NaN
# 4   2014-04-19 13:28:00.810   -6.7547   155.0241   43.37  7.5     mww  NaN
# 5   2014-04-13 12:36:19.230  -11.4633   162.0511   39.00  7.4     mww  NaN
# 6   2014-10-14 03:51:34.460   12.5262   -88.1225   40.00  7.3     mww  NaN
# 7   2014-04-18 14:27:24.920   17.3970  -100.9723   24.00  7.2     mww  NaN
# 8   2014-04-11 07:07:23.130   -6.5858   155.0485   60.53  7.1     mww  NaN
# 9   2014-11-15 02:31:41.720    1.8929   126.5217   45.00  7.1     mww  NaN
# 10  2014-11-01 18:57:22.380  -19.6903  -177.7587  434.00  7.1     mww  NaN
# ...

# %%
#创建画布以及axes(GeoAxes)
proj = ccrs.Robinson(central_longitude=180) #定义Robinson投影
fig = plt.figure(figsize=(14,7),dpi=100)
ax = fig.add_subplot(1,1,1, projection= proj)

#优化地图显示
ax.coastlines() #绘制海岸线
ax.set_global() #让地图的显示范围扩展至投影的最大范围
ax.stock_img()  # 添加低分辨率的地形图

#绘制地震数据
plt.scatter(Sig_Eqs_top50.longitude,Sig_Eqs_top50.latitude,c=Sig_Eqs_top50.mag,cmap='Reds',edgecolors='k',transform=ccrs.PlateCarree())
plt.colorbar(shrink=0.6,label='magnitude')
plt.title('Top 50 earthquakes at 2014')

#输出PNG图片结果保存
plt.savefig('Top 50 earthquakes at 2014.png', dpi=300, bbox_inches='tight')

plt.show()
# Out:
# D:\Anaconda\envs\ese5023\lib\site-packages\cartopy\crs.py:825: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# D:\Anaconda\envs\ese5023\lib\site-packages\cartopy\crs.py:836: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# D:\Anaconda\envs\ese5023\lib\site-packages\cartopy\crs.py:836: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# ...
